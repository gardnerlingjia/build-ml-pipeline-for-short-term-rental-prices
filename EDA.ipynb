# %%
import wandb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# /home/lingjia/miniconda3/envs/mlops-course/lib/python3.8/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# wandb: Currently logged in as: gardner-lingjia-cariad (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.26.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.21<br/>
#                 Syncing run <strong style="color:#cdcd00">graceful-spaceship-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/gardner-lingjia-cariad/nyc_airbnb" target="_blank">https://wandb.ai/gardner-lingjia-cariad/nyc_airbnb</a><br/>
#                 Run page: <a href="https://wandb.ai/gardner-lingjia-cariad/nyc_airbnb/runs/l4amop25" target="_blank">https://wandb.ai/gardner-lingjia-cariad/nyc_airbnb/runs/l4amop25</a><br/>
#                 Run data is saved locally in <code>/home/lingjia/Documents/build-ml-pipeline-for-short-term-rental-prices/wandb/run-20260422_190550-l4amop25</code><br/><br/>

# %%
df.head()
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB
# id                                   0
# name                                 7
# host_id                              0
# host_name                            8
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       4123
# reviews_per_month                 4123
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
df.describe()
df["price"].describe()
# Out:
# count    20000.000000
# mean       153.269050
# std        243.325609
# min          0.000000
# 25%         69.000000
# 50%        105.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8,4))
sns.histplot(df["price"], bins=50, kde=True)
plt.show()

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()

# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 37287<br/>Program ended successfully.
# /home/lingjia/miniconda3/envs/mlops-course/lib/python3.8/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Find user logs for this run at: <code>/home/lingjia/Documents/build-ml-pipeline-for-short-term-rental-prices/wandb/run-20260422_190550-l4amop25/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/lingjia/Documents/build-ml-pipeline-for-short-term-rental-prices/wandb/run-20260422_190550-l4amop25/logs/debug-internal.log</code>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">graceful-spaceship-9</strong>: <a href="https://wandb.ai/gardner-lingjia-cariad/nyc_airbnb/runs/l4amop25" target="_blank">https://wandb.ai/gardner-lingjia-cariad/nyc_airbnb/runs/l4amop25</a><br/>
